# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# from sklearn.linear_model import LinearRegression

# %matplotlib inline

sns.set()

# %%
r_insurance_df = pd.read_csv('health_insurance.csv')
r_access_df = pd.read_csv('healthcare_access.csv')

# %%
r_insurance_df
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 0      60.0    male      64  24.3           NoDisease                 1
# 1      49.0  female      75  22.6           NoDisease                 1
# 2      32.0  female      64  17.8            Epilepsy                 2
# 3      61.0  female      53  36.4           NoDisease                 1
# 4      19.0  female      50  20.6           NoDisease                 0
# ...     ...     ...     ...   ...                 ...               ...
# 14995  39.0    male      49  28.3           NoDisease                 1
# 14996  39.0    male      74  29.6           NoDisease                 4
# 14997  20.0    male      62  33.3           NoDisease                 0
# 14998  52.0    male      88  36.7           NoDisease                 0
# 14999  52.0    male      57  26.4           NoDisease                 3
#
#        smoker         city  bloodpressure  diabetes  regular_ex  \
# 0           0      NewYork             72         0           0
# 1           0       Boston             78         1           1
# 2           1  Phildelphia             88         1           1
# 3           1    Pittsburg             72         1           0
# 4           0      Buffalo             82         1           0
# ...       ...          ...            ...       ...         ...
# 14995       1     Florence             54         1           0
# 14996       0        Miami             64         1           0
# 14997       0        Tampa             52         1           0
# 14998       0   PanamaCity             70         1           0
# 14999       0    Kingsport             72         1           0
#
#              job_title    claim
# 0                Actor  13112.6
# 1             Engineer   9567.0
# 2          Academician  32734.2
# 3                 Chef  48517.6
# 4           HomeMakers   1731.7
# ...                ...      ...
# 14995        FilmMaker  21082.2
# 14996          Student   7512.3
# 14997  FashionDesigner   1391.5
# 14998           Farmer   9144.6
# 14999          Manager  25992.8
#
# [15000 rows x 13 columns]

# %%
r_access_df
# Out:
#       Year                                     State     Yes      No  \
# 0     2010  Nationwide (States, DC, and Territories)     85%     15%
# 1     2010                Nationwide (States and DC)     85%     15%
# 2     2010                                      Guam  77.80%  22.20%
# 3     2010                               Puerto Rico  92.10%   7.90%
# 4     2010                            Virgin Islands  69.40%  30.60%
# ...    ...                                       ...     ...     ...
# 1635  2010                                   Alabama  79.90%  20.10%
# 1636  1996                               Mississippi  82.70%  17.30%
# 1637  1996                                  Virginia  85.40%  14.60%
# 1638  2006                                   Wyoming  82.10%  17.90%
# 1639  1996                                 Tennessee  86.10%  13.90%
#
#                          Category  \
# 0     Health Care Access/Coverage
# 1     Health Care Access/Coverage
# 2     Health Care Access/Coverage
# 3     Health Care Access/Coverage
# 4     Health Care Access/Coverage
# ...                           ...
# 1635  Health Care Access/Coverage
# 1636  Health Care Access/Coverage
# 1637  Health Care Access/Coverage
# 1638  Health Care Access/Coverage
# 1639  Health Care Access/Coverage
#
#                                               Condition  \
# 0         Do you have any kind of health care coverage?
# 1         Do you have any kind of health care coverage?
# 2         Do you have any kind of health care coverage?
# 3         Do you have any kind of health care coverage?
# 4         Do you have any kind of health care coverage?
# ...                                                 ...
# 1635  Adults aged 18-64 who have any kind of health ...
# 1636  Adults aged 18-64 who have any kind of health ...
# 1637      Do you have any kind of health care coverage?
# 1638      Do you have any kind of health care coverage?
# 1639  Adults aged 18-64 who have any kind of health ...
#
#                                              Location 1
# 0            Nationwide (States, DC, and Territories)\n
# 1                          Nationwide (States and DC)\n
# 2                                                Guam\n
# 3                                         Puerto Rico\n
# 4                                      Virgin Islands\n
# ...                                                 ...
# 1635   Alabama\n(32.84057112200048, -86.63186076199969)
# 1636  Mississippi\n(32.745510099000455, -89.53803082...
# 1637  Virginia\n(37.54268067400045, -78.45789046299967)
# 1638  Wyoming\n(43.23554134300048, -108.10983035299967)
# 1639  Tennessee\n(35.68094058000048, -85.77449091399...
#
# [1640 rows x 7 columns]

# %%
r_insurance_df.info(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  14604 non-null  float64
#  1   sex                  15000 non-null  object
#  2   weight               15000 non-null  int64
#  3   bmi                  14044 non-null  float64
#  4   hereditary_diseases  15000 non-null  object
#  5   no_of_dependents     15000 non-null  int64
#  6   smoker               15000 non-null  int64
#  7   city                 15000 non-null  object
#  8   bloodpressure        15000 non-null  int64
#  9   diabetes             15000 non-null  int64
#  10  regular_ex           15000 non-null  int64
#  11  job_title            15000 non-null  object
#  12  claim                15000 non-null  float64
# dtypes: float64(3), int64(6), object(4)
# memory usage: 1.5+ MB

# %%
r_access_df.info(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1640 entries, 0 to 1639
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        1640 non-null   int64
#  1   State       1640 non-null   object
#  2   Yes         1640 non-null   object
#  3   No          1640 non-null   object
#  4   Category    1640 non-null   object
#  5   Condition   1640 non-null   object
#  6   Location 1  1640 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 89.8+ KB

# %%
insurance_df = r_insurance_df.copy()

access_df = r_access_df.copy()

# %%
insurance_df.head()
# Out:
#     age     sex  weight   bmi hereditary_diseases  no_of_dependents  smoker  \
# 0  60.0    male      64  24.3           NoDisease                 1       0
# 1  49.0  female      75  22.6           NoDisease                 1       0
# 2  32.0  female      64  17.8            Epilepsy                 2       1
# 3  61.0  female      53  36.4           NoDisease                 1       1
# 4  19.0  female      50  20.6           NoDisease                 0       0
#
#           city  bloodpressure  diabetes  regular_ex    job_title    claim
# 0      NewYork             72         0           0        Actor  13112.6
# 1       Boston             78         1           1     Engineer   9567.0
# 2  Phildelphia             88         1           1  Academician  32734.2
# 3    Pittsburg             72         1           0         Chef  48517.6
# 4      Buffalo             82         1           0   HomeMakers   1731.7

# %%
insurance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  14604 non-null  float64
#  1   sex                  15000 non-null  object
#  2   weight               15000 non-null  int64
#  3   bmi                  14044 non-null  float64
#  4   hereditary_diseases  15000 non-null  object
#  5   no_of_dependents     15000 non-null  int64
#  6   smoker               15000 non-null  int64
#  7   city                 15000 non-null  object
#  8   bloodpressure        15000 non-null  int64
#  9   diabetes             15000 non-null  int64
#  10  regular_ex           15000 non-null  int64
#  11  job_title            15000 non-null  object
#  12  claim                15000 non-null  float64
# dtypes: float64(3), int64(6), object(4)
# memory usage: 1.5+ MB

# %%
insurance_df.shape
# Out:
# (15000, 13)

# %%
insurance_df.columns.to_list()
# Out:
# ['age',
#  'sex',
#  'weight',
#  'bmi',
#  'hereditary_diseases',
#  'no_of_dependents',
#  'smoker',
#  'city',
#  'bloodpressure',
#  'diabetes',
#  'regular_ex',
#  'job_title',
#  'claim']

# %%
access_df.head()
# Out:
#    Year                                     State     Yes      No  \
# 0  2010  Nationwide (States, DC, and Territories)     85%     15%
# 1  2010                Nationwide (States and DC)     85%     15%
# 2  2010                                      Guam  77.80%  22.20%
# 3  2010                               Puerto Rico  92.10%   7.90%
# 4  2010                            Virgin Islands  69.40%  30.60%
#
#                       Category                                      Condition  \
# 0  Health Care Access/Coverage  Do you have any kind of health care coverage?
# 1  Health Care Access/Coverage  Do you have any kind of health care coverage?
# 2  Health Care Access/Coverage  Do you have any kind of health care coverage?
# 3  Health Care Access/Coverage  Do you have any kind of health care coverage?
# 4  Health Care Access/Coverage  Do you have any kind of health care coverage?
#
#                                    Location 1
# 0  Nationwide (States, DC, and Territories)\n
# 1                Nationwide (States and DC)\n
# 2                                      Guam\n
# 3                               Puerto Rico\n
# 4                            Virgin Islands\n

# %%
access_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1640 entries, 0 to 1639
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        1640 non-null   int64
#  1   State       1640 non-null   object
#  2   Yes         1640 non-null   object
#  3   No          1640 non-null   object
#  4   Category    1640 non-null   object
#  5   Condition   1640 non-null   object
#  6   Location 1  1640 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 89.8+ KB

# %%
access_df.shape
# Out:
# (1640, 7)

# %%
access_df.columns.to_list()
# Out:
# ['Year', 'State', 'Yes', 'No', 'Category', 'Condition', 'Location 1']

# %%
access_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1640 entries, 0 to 1639
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        1640 non-null   int64
#  1   State       1640 non-null   object
#  2   Yes         1640 non-null   object
#  3   No          1640 non-null   object
#  4   Category    1640 non-null   object
#  5   Condition   1640 non-null   object
#  6   Location 1  1640 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 89.8+ KB

# %%
insurance_df.isna().sum()
# Out:
# age                    396
# sex                      0
# weight                   0
# bmi                    956
# hereditary_diseases      0
# no_of_dependents         0
# smoker                   0
# city                     0
# bloodpressure            0
# diabetes                 0
# regular_ex               0
# job_title                0
# claim                    0
# dtype: int64

# %%
access_df.isna().sum()
# Out:
# Year          0
# State         0
# Yes           0
# No            0
# Category      0
# Condition     0
# Location 1    0
# dtype: int64

# %% [markdown]
# ## Analysis

# %%
plt.figure(figsize=(8,8))
sns.displot(insurance_df['age'])
plt.title("Age Distribution")
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.countplot(insurance_df['sex'])
plt.title("Gender Distribution")
plt.show()
print(insurance_df["sex"].value_counts())
# Out:
# /Users/cuddoongaraado/opt/anaconda3/envs/data_capstone_venv/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# female    7652
# male      7348
# Name: sex, dtype: int64

# %%
plt.figure(figsize=(8,8));
sns.displot(insurance_df['weight']);
plt.title("Weight Distribution");
plt.show();

# %%
plt.figure(figsize=(8,8));
sns.displot(insurance_df['bmi']);
plt.title("BMI Distribution");
plt.show();

# %%
plt.figure(figsize=(8,8));
sns.countplot(insurance_df['hereditary_diseases']);
plt.title("Hereditary Diseases Distribution");
plt.xticks(rotation = 45)
plt.show();
print(insurance_df["hereditary_diseases"].value_counts());
# Out:
# /Users/cuddoongaraado/opt/anaconda3/envs/data_capstone_venv/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# NoDisease       13998
# Diabetes          148
# Alzheimer         144
# Obesity           136
# EyeDisease        123
# Cancer            109
# Arthritis          96
# HeartDisease       93
# Epilepsy           84
# High BP            69
# Name: hereditary_diseases, dtype: int64

# %%
plt.figure(figsize=(8,8));
sns.countplot(insurance_df['no_of_dependents']);
plt.title("Number of Dependents Distribution");
plt.show();
# Out:
# /Users/cuddoongaraado/opt/anaconda3/envs/data_capstone_venv/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(8,8));
sns.countplot(insurance_df['smoker']);
plt.title("Smoker Distribution");
plt.show();
print(insurance_df["smoker"].value_counts());
# Out:
# /Users/cuddoongaraado/opt/anaconda3/envs/data_capstone_venv/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# 0    12028
# 1     2972
# Name: smoker, dtype: int64

# %%
plt.figure(figsize=(8,8));
sns.countplot(insurance_df['diabetes']);
plt.title("Diabetes Distribution");
plt.show();
# Out:
# /Users/cuddoongaraado/opt/anaconda3/envs/data_capstone_venv/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(8,8));
sns.countplot(insurance_df['regular_ex']);
plt.title("Regular Excercise Distribution");
plt.show();
# Out:
# /Users/cuddoongaraado/opt/anaconda3/envs/data_capstone_venv/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(8,8));
sns.displot(insurance_df['claim']);
plt.title("Claim Distribution");
plt.show();

# %% [markdown]
# ## Data Cleaning

# %%
insurance_df.columns = insurance_df.columns.str.lower()

insurance_df.head()
# Out:
#     age     sex  weight   bmi hereditary_diseases  no_of_dependents  smoker  \
# 0  60.0    male      64  24.3           NoDisease                 1       0
# 1  49.0  female      75  22.6           NoDisease                 1       0
# 2  32.0  female      64  17.8            Epilepsy                 2       1
# 3  61.0  female      53  36.4           NoDisease                 1       1
# 4  19.0  female      50  20.6           NoDisease                 0       0
#
#           city  bloodpressure  diabetes  regular_ex    job_title    claim
# 0      NewYork             72         0           0        Actor  13112.6
# 1       Boston             78         1           1     Engineer   9567.0
# 2  Phildelphia             88         1           1  Academician  32734.2
# 3    Pittsburg             72         1           0         Chef  48517.6
# 4      Buffalo             82         1           0   HomeMakers   1731.7

# %%
insurance_df.drop(columns=['bloodpressure'],inplace=True)
insurance_df
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 0      60.0    male      64  24.3           NoDisease                 1
# 1      49.0  female      75  22.6           NoDisease                 1
# 2      32.0  female      64  17.8            Epilepsy                 2
# 3      61.0  female      53  36.4           NoDisease                 1
# 4      19.0  female      50  20.6           NoDisease                 0
# ...     ...     ...     ...   ...                 ...               ...
# 14995  39.0    male      49  28.3           NoDisease                 1
# 14996  39.0    male      74  29.6           NoDisease                 4
# 14997  20.0    male      62  33.3           NoDisease                 0
# 14998  52.0    male      88  36.7           NoDisease                 0
# 14999  52.0    male      57  26.4           NoDisease                 3
#
#        smoker         city  diabetes  regular_ex        job_title    claim
# 0           0      NewYork         0           0            Actor  13112.6
# 1           0       Boston         1           1         Engineer   9567.0
# 2           1  Phildelphia         1           1      Academician  32734.2
# 3           1    Pittsburg         1           0             Chef  48517.6
# 4           0      Buffalo         1           0       HomeMakers   1731.7
# ...       ...          ...       ...         ...              ...      ...
# 14995       1     Florence         1           0        FilmMaker  21082.2
# 14996       0        Miami         1           0          Student   7512.3
# 14997       0        Tampa         1           0  FashionDesigner   1391.5
# 14998       0   PanamaCity         1           0           Farmer   9144.6
# 14999       0    Kingsport         1           0          Manager  25992.8
#
# [15000 rows x 12 columns]

# %%
access_df.columns = access_df.columns.str.lower()
access_df.head()
# Out:
#    year                                     state     yes      no  \
# 0  2010  Nationwide (States, DC, and Territories)     85%     15%
# 1  2010                Nationwide (States and DC)     85%     15%
# 2  2010                                      Guam  77.80%  22.20%
# 3  2010                               Puerto Rico  92.10%   7.90%
# 4  2010                            Virgin Islands  69.40%  30.60%
#
#                       category                                      condition  \
# 0  Health Care Access/Coverage  Do you have any kind of health care coverage?
# 1  Health Care Access/Coverage  Do you have any kind of health care coverage?
# 2  Health Care Access/Coverage  Do you have any kind of health care coverage?
# 3  Health Care Access/Coverage  Do you have any kind of health care coverage?
# 4  Health Care Access/Coverage  Do you have any kind of health care coverage?
#
#                                    location 1
# 0  Nationwide (States, DC, and Territories)\n
# 1                Nationwide (States and DC)\n
# 2                                      Guam\n
# 3                               Puerto Rico\n
# 4                            Virgin Islands\n

# %%
access_df.drop(columns=['location 1'],inplace=True)
access_df
# Out:
#       year                                     state     yes      no  \
# 0     2010  Nationwide (States, DC, and Territories)     85%     15%
# 1     2010                Nationwide (States and DC)     85%     15%
# 2     2010                                      Guam  77.80%  22.20%
# 3     2010                               Puerto Rico  92.10%   7.90%
# 4     2010                            Virgin Islands  69.40%  30.60%
# ...    ...                                       ...     ...     ...
# 1635  2010                                   Alabama  79.90%  20.10%
# 1636  1996                               Mississippi  82.70%  17.30%
# 1637  1996                                  Virginia  85.40%  14.60%
# 1638  2006                                   Wyoming  82.10%  17.90%
# 1639  1996                                 Tennessee  86.10%  13.90%
#
#                          category  \
# 0     Health Care Access/Coverage
# 1     Health Care Access/Coverage
# 2     Health Care Access/Coverage
# 3     Health Care Access/Coverage
# 4     Health Care Access/Coverage
# ...                           ...
# 1635  Health Care Access/Coverage
# 1636  Health Care Access/Coverage
# 1637  Health Care Access/Coverage
# 1638  Health Care Access/Coverage
# 1639  Health Care Access/Coverage
#
#                                               condition
# 0         Do you have any kind of health care coverage?
# 1         Do you have any kind of health care coverage?
# 2         Do you have any kind of health care coverage?
# 3         Do you have any kind of health care coverage?
# 4         Do you have any kind of health care coverage?
# ...                                                 ...
# 1635  Adults aged 18-64 who have any kind of health ...
# 1636  Adults aged 18-64 who have any kind of health ...
# 1637      Do you have any kind of health care coverage?
# 1638      Do you have any kind of health care coverage?
# 1639  Adults aged 18-64 who have any kind of health ...
#
# [1640 rows x 6 columns]

# %%
access_df.drop(columns=['condition'],inplace=True)
access_df
# Out:
#       year                                     state     yes      no  \
# 0     2010  Nationwide (States, DC, and Territories)     85%     15%
# 1     2010                Nationwide (States and DC)     85%     15%
# 2     2010                                      Guam  77.80%  22.20%
# 3     2010                               Puerto Rico  92.10%   7.90%
# 4     2010                            Virgin Islands  69.40%  30.60%
# ...    ...                                       ...     ...     ...
# 1635  2010                                   Alabama  79.90%  20.10%
# 1636  1996                               Mississippi  82.70%  17.30%
# 1637  1996                                  Virginia  85.40%  14.60%
# 1638  2006                                   Wyoming  82.10%  17.90%
# 1639  1996                                 Tennessee  86.10%  13.90%
#
#                          category
# 0     Health Care Access/Coverage
# 1     Health Care Access/Coverage
# 2     Health Care Access/Coverage
# 3     Health Care Access/Coverage
# 4     Health Care Access/Coverage
# ...                           ...
# 1635  Health Care Access/Coverage
# 1636  Health Care Access/Coverage
# 1637  Health Care Access/Coverage
# 1638  Health Care Access/Coverage
# 1639  Health Care Access/Coverage
#
# [1640 rows x 5 columns]

# %%
access_df.drop(columns=['category'],inplace=True)
access_df
# Out:
#       year                                     state     yes      no
# 0     2010  Nationwide (States, DC, and Territories)     85%     15%
# 1     2010                Nationwide (States and DC)     85%     15%
# 2     2010                                      Guam  77.80%  22.20%
# 3     2010                               Puerto Rico  92.10%   7.90%
# 4     2010                            Virgin Islands  69.40%  30.60%
# ...    ...                                       ...     ...     ...
# 1635  2010                                   Alabama  79.90%  20.10%
# 1636  1996                               Mississippi  82.70%  17.30%
# 1637  1996                                  Virginia  85.40%  14.60%
# 1638  2006                                   Wyoming  82.10%  17.90%
# 1639  1996                                 Tennessee  86.10%  13.90%
#
# [1640 rows x 4 columns]

# %%
insurance_df.city.nunique()
# Out:
# 91

# %%
insurance_df.city.unique()
# Out:
# array(['NewYork', 'Boston', 'Phildelphia', 'Pittsburg', 'Buffalo',
#        'AtlanticCity', 'Portland', 'Cambridge', 'Hartford', 'Springfield',
#        'Syracuse', 'Baltimore', 'York', 'Trenton', 'Warwick',
#        'WashingtonDC', 'Providence', 'Harrisburg', 'Newport', 'Stamford',
#        'Worcester', 'Atlanta', 'Brimingham', 'Charleston', 'Charlotte',
#        'Louisville', 'Memphis', 'Nashville', 'NewOrleans', 'Raleigh',
#        'Houston', 'Georgia', 'Oklahoma', 'Orlando', 'Macon', 'Huntsville',
#        'Knoxville', 'Florence', 'Miami', 'Tampa', 'PanamaCity',
#        'Kingsport', 'Marshall', 'Mandan', 'Waterloo', 'IowaCity',
#        'Columbia', 'Indianapolis', 'Cincinnati', 'Bloomington', 'Salina',
#        'KanasCity', 'Brookings', 'Minot', 'Chicago', 'Lincoln',
#        'FallsCity', 'GrandForks', 'Fargo', 'Cleveland', 'Canton',
#        'Columbus', 'Rochester', 'Minneapolis', 'JeffersonCity',
#        'Escabana', 'Youngstown', 'SantaRosa', 'Eureka', 'SanFrancisco',
#        'SanJose', 'LosAngeles', 'Oxnard', 'SanDeigo', 'Oceanside',
#        'Carlsbad', 'Montrose', 'Prescott', 'Fresno', 'Reno', 'LasVegas',
#        'Tucson', 'SanLuis', 'Denver', 'Kingman', 'Bakersfield',
#        'Mexicali', 'SilverCity', 'Pheonix', 'SantaFe', 'Lovelock'],
#       dtype=object)

# %%
insurance_df.replace({'Boston':'MA'}, inplace=True)

# %%
insurance_df.city.unique()
# Out:
# array(['NewYork', 'MA', 'Phildelphia', 'Pittsburg', 'Buffalo',
#        'AtlanticCity', 'Portland', 'Cambridge', 'Hartford', 'Springfield',
#        'Syracuse', 'Baltimore', 'York', 'Trenton', 'Warwick',
#        'WashingtonDC', 'Providence', 'Harrisburg', 'Newport', 'Stamford',
#        'Worcester', 'Atlanta', 'Brimingham', 'Charleston', 'Charlotte',
#        'Louisville', 'Memphis', 'Nashville', 'NewOrleans', 'Raleigh',
#        'Houston', 'Georgia', 'Oklahoma', 'Orlando', 'Macon', 'Huntsville',
#        'Knoxville', 'Florence', 'Miami', 'Tampa', 'PanamaCity',
#        'Kingsport', 'Marshall', 'Mandan', 'Waterloo', 'IowaCity',
#        'Columbia', 'Indianapolis', 'Cincinnati', 'Bloomington', 'Salina',
#        'KanasCity', 'Brookings', 'Minot', 'Chicago', 'Lincoln',
#        'FallsCity', 'GrandForks', 'Fargo', 'Cleveland', 'Canton',
#        'Columbus', 'Rochester', 'Minneapolis', 'JeffersonCity',
#        'Escabana', 'Youngstown', 'SantaRosa', 'Eureka', 'SanFrancisco',
#        'SanJose', 'LosAngeles', 'Oxnard', 'SanDeigo', 'Oceanside',
#        'Carlsbad', 'Montrose', 'Prescott', 'Fresno', 'Reno', 'LasVegas',
#        'Tucson', 'SanLuis', 'Denver', 'Kingman', 'Bakersfield',
#        'Mexicali', 'SilverCity', 'Pheonix', 'SantaFe', 'Lovelock'],
#       dtype=object)

# %%
access_df.state.unique()
# Out:
# array(['Nationwide (States, DC, and Territories)',
#        'Nationwide (States and DC)', 'Guam', 'Puerto Rico',
#        'Virgin Islands', 'New Jersey', 'Texas', 'South Carolina',
#        'Virginia', 'Kentucky', 'Connecticut', 'Arizona', 'Oregon',
#        'Idaho', 'Vermont', 'Missouri', 'Oklahoma', 'Montana', 'Louisiana',
#        'Indiana', 'Florida', 'New Hampshire', 'Kansas',
#        'District of Columbia', 'New Mexico', 'Alabama', 'California',
#        'Wyoming', 'New York', 'South Dakota', 'Nevada', 'Maryland',
#        'Iowa', 'Massachusetts', 'Maine', 'North Carolina', 'Rhode Island',
#        'Nebraska', 'Arkansas', 'Mississippi', 'Minnesota', 'Hawaii',
#        'Tennessee', 'North Dakota', 'West Virginia', 'Colorado',
#        'Illinois', 'Utah', 'Alaska', 'Delaware', 'Michigan', 'Washington',
#        'Ohio', 'Wisconsin', 'Georgia', 'Pennsylvania'], dtype=object)

# %%
access_df.replace({"Alabama": "AL", "Alaska": "AK", "Arizona": "AZ", "Arkansas": "AR", "California": "CA", "Colorado": "CO", "Connecticut": "CT", "Delaware": "DE", "Florida": "FL", "Georgia": "GA", "Hawaii": "HI", "Idaho": "ID", "Illinois": "IL", "Indiana": "IN", "Iowa": "IA", "Kansas": "KS", "Kentucky": "KY", "Louisiana": "LA", "Maine": "ME", "Maryland": "MD", "Massachusetts": "MA", "Michigan": "MI", "Minnesota": "MN", "Mississippi": "MS", "Missouri": "MO", "Montana": "MT", "Nebraska": "NE", "Nevada": "NV", "New Hampshire": "NH", "New Jersey": "NJ", "New Mexico": "NM", "New York": "NY", "North Carolina": "NC", "North Dakota": "ND", "Ohio": "OH", "Oklahoma": "OK", "Oregon": "OR", "Pennsylvania": "PA", "Rhode Island": "RI", "South Carolina": "SC", "South Dakota": "SD", "Tennessee": "TN", "Texas": "TX", "Utah": "UT", "Vermont": "VT", "Virginia": "VA", "Washington": "WA", "West Virginia": "WV", "Wisconsin": "WI", "Wyoming": "WY"}, inplace=True)
access_df
# Out:
#       year                                     state     yes      no
# 0     2010  Nationwide (States, DC, and Territories)     85%     15%
# 1     2010                Nationwide (States and DC)     85%     15%
# 2     2010                                      Guam  77.80%  22.20%
# 3     2010                               Puerto Rico  92.10%   7.90%
# 4     2010                            Virgin Islands  69.40%  30.60%
# ...    ...                                       ...     ...     ...
# 1635  2010                                        AL  79.90%  20.10%
# 1636  1996                                        MS  82.70%  17.30%
# 1637  1996                                        VA  85.40%  14.60%
# 1638  2006                                        WY  82.10%  17.90%
# 1639  1996                                        TN  86.10%  13.90%
#
# [1640 rows x 4 columns]

# %%
access_df.describe()
# Out:
#               year
# count  1640.000000
# mean   2002.665854
# std       4.735653
# min    1995.000000
# 25%    1998.000000
# 50%    2003.000000
# 75%    2007.000000
# max    2010.000000

# %%
insurance_df.describe()
# Out:
#                 age        weight           bmi  no_of_dependents  \
# count  14604.000000  15000.000000  14044.000000      15000.000000
# mean      39.547521     64.909600     30.266413          1.129733
# std       14.015966     13.701935      6.122950          1.228469
# min       18.000000     34.000000     16.000000          0.000000
# 25%       27.000000     54.000000     25.700000          0.000000
# 50%       40.000000     63.000000     29.400000          1.000000
# 75%       52.000000     76.000000     34.400000          2.000000
# max       64.000000     95.000000     53.100000          5.000000
#
#              smoker      diabetes    regular_ex         claim
# count  15000.000000  15000.000000  15000.000000  15000.000000
# mean       0.198133      0.777000      0.224133  13401.437620
# std        0.398606      0.416272      0.417024  12148.239619
# min        0.000000      0.000000      0.000000   1121.900000
# 25%        0.000000      1.000000      0.000000   4846.900000
# 50%        0.000000      1.000000      0.000000   9545.650000
# 75%        0.000000      1.000000      0.000000  16519.125000
# max        1.000000      1.000000      1.000000  63770.400000

# %%
insurance_df.replace({'NewYork': 'NY', 'Phildelphia': 'PA', 'Pittsburg': 'PA', 'Buffalo': 'NY', 'Portland': 'OR', 'Atlanta': 'GA', 'Brimingham': 'AL', 'Louisville': 'KY', 'Memphis': 'TN', 'Nashville': 'TN', 'NewOrleans': 'LA', 'Raleigh': 'NC', 'Houston': 'TX', 'Georgia': 'GA', 'Oklahoma': 'OK', 'Orlando': 'FL', 'Columbus':'OH', 'Rochester': 'MN', 'Minneapolis': 'MN', 'SanFrancisco': 'CA', 'SanJose': 'CA', 'LosAngeles': 'CA', 'Oxnard': 'CA', 'SanDeigo': 'CA', 'Oceanside': 'CA', 'Carlsbad': 'CA', 'Montrose': 'CO', 'Prescott': 'AZ', 'Fresno': 'CA', 'Reno': 'NV', 'LasVegas': 'NV', 'Tucson': 'AZ', 'Denver': 'CO', 'GrandForks': 'ND', 'Fargo': 'ND', 'Cleveland': 'OH', 'Indianapolis': 'IN', 'Cincinnati': 'OH', 'Chicago': 'IL', 'Miami': 'FL', 'Tampa': 'FL', 'IowaCity': 'IA', 'Pheonix': 'AZ', 'SantaFe': 'NM',  'AtlanticCity': 'NJ', 'Cambridge': 'MA', 'Hartford': 'CT', 'Springfield': 'IL',  'Syracuse': 'NY', 'Baltimore': 'MD', 'KanasCity': 'MS', 'Bakersfield': 'CA', 'Newport': 'NJ', 'Providence': 'RI', 'Harrisburg': 'PA', 'Stamford': 'CT',  'Worcester': 'MA', 'Charleston': 'SC', 'Charlotte': 'NC','Macon': 'GA', 'Huntsville': 'AL', 'Knoxville': 'KY', 'Florence': 'SC', 'PanamaCity': 'FL', 'Kingsport': 'TN', 'Marshall': 'TX', 'Mandan': 'ND', 'Waterloo': 'IA', 'Columbia': 'SC', 'Bloomington': 'IN', 'Salina': 'KS', 'Brookings': 'SD', 'Minot': 'ND', 'Lincoln': 'NE', 'FallsCity': 'NE', 'Canton': 'OH', 'JeffersonCity': 'MS', 'Escabana': 'MI', 'Youngstown': 'OH', 'SantaRosa': 'CA', 'Eureka': 'CA', 'Kingman': 'AZ', 'SanLuis': 'AZ',  'Mexicali': 'CA', 'SilverCity': 'NM', 'WashingtonDC': 'DC', 'Lovelock': 'NV'}, inplace=True)
insurance_df
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 0      60.0    male      64  24.3           NoDisease                 1
# 1      49.0  female      75  22.6           NoDisease                 1
# 2      32.0  female      64  17.8            Epilepsy                 2
# 3      61.0  female      53  36.4           NoDisease                 1
# 4      19.0  female      50  20.6           NoDisease                 0
# ...     ...     ...     ...   ...                 ...               ...
# 14995  39.0    male      49  28.3           NoDisease                 1
# 14996  39.0    male      74  29.6           NoDisease                 4
# 14997  20.0    male      62  33.3           NoDisease                 0
# 14998  52.0    male      88  36.7           NoDisease                 0
# 14999  52.0    male      57  26.4           NoDisease                 3
#
#        smoker city  diabetes  regular_ex        job_title    claim
# 0           0   NY         0           0            Actor  13112.6
# 1           0   MA         1           1         Engineer   9567.0
# 2           1   PA         1           1      Academician  32734.2
# 3           1   PA         1           0             Chef  48517.6
# 4           0   NY         1           0       HomeMakers   1731.7
# ...       ...  ...       ...         ...              ...      ...
# 14995       1   SC         1           0        FilmMaker  21082.2
# 14996       0   FL         1           0          Student   7512.3
# 14997       0   FL         1           0  FashionDesigner   1391.5
# 14998       0   FL         1           0           Farmer   9144.6
# 14999       0   TN         1           0          Manager  25992.8
#
# [15000 rows x 12 columns]

# %%
insurance_df.hereditary_diseases.unique()
# Out:
# array(['NoDisease', 'Epilepsy', 'EyeDisease', 'Alzheimer', 'Arthritis',
#        'HeartDisease', 'Diabetes', 'Cancer', 'High BP', 'Obesity'],
#       dtype=object)

# %%
insurance_df.replace({'hereditary_diseases':{'NoDisease':0, 'Epilepsy':1, 'EyeDisease':1, 'Alzheimer':1, 'Arthritis':1,
       'HeartDisease':1, 'Diabetes':1, 'Cancer':1, 'High BP':1, 'Obesity':1}}, inplace= True)

# %%
insurance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  14604 non-null  float64
#  1   sex                  15000 non-null  object
#  2   weight               15000 non-null  int64
#  3   bmi                  14044 non-null  float64
#  4   hereditary_diseases  15000 non-null  int64
#  5   no_of_dependents     15000 non-null  int64
#  6   smoker               15000 non-null  int64
#  7   city                 15000 non-null  object
#  8   diabetes             15000 non-null  int64
#  9   regular_ex           15000 non-null  int64
#  10  job_title            15000 non-null  object
#  11  claim                15000 non-null  float64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 1.4+ MB

# %%
plt.figure(figsize=(8,8))
sns.countplot(insurance_df['hereditary_diseases'])
plt.title("Hereditary Diseases Distribution")
plt.xticks(rotation = 45)
plt.show()
print(insurance_df["hereditary_diseases"].value_counts())
# Out:
# /Users/cuddoongaraado/opt/anaconda3/envs/data_capstone_venv/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# 0    13998
# 1     1002
# Name: hereditary_diseases, dtype: int64

# %%
insurance_df.replace({'sex':{'male':0, 'female':1}},inplace = True)

# %%
insurance_df.head()
# Out:
#     age  sex  weight   bmi  hereditary_diseases  no_of_dependents  smoker  \
# 0  60.0    0      64  24.3                    0                 1       0
# 1  49.0    1      75  22.6                    0                 1       0
# 2  32.0    1      64  17.8                    1                 2       1
# 3  61.0    1      53  36.4                    0                 1       1
# 4  19.0    1      50  20.6                    0                 0       0
#
#   city  diabetes  regular_ex    job_title    claim
# 0   NY         0           0        Actor  13112.6
# 1   MA         1           1     Engineer   9567.0
# 2   PA         1           1  Academician  32734.2
# 3   PA         1           0         Chef  48517.6
# 4   NY         1           0   HomeMakers   1731.7

# %%
plt.figure(figsize=(8,8))
sns.countplot(insurance_df['sex'])
plt.title("Gender Distribution")
plt.show()
print(insurance_df["sex"].value_counts())
# Out:
# /Users/cuddoongaraado/opt/anaconda3/envs/data_capstone_venv/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# 1    7652
# 0    7348
# Name: sex, dtype: int64

# %%
insurance_df.job_title.unique()
# Out:
# array(['Actor', 'Engineer', 'Academician', 'Chef', 'HomeMakers', 'Dancer',
#        'Singer', 'DataScientist', 'Police', 'Student', 'Doctor',
#        'Manager', 'Photographer', 'Beautician', 'CA', 'Blogger', 'CEO',
#        'Labourer', 'Accountant', 'FilmDirector', 'Technician',
#        'FashionDesigner', 'Architect', 'HouseKeeper', 'FilmMaker',
#        'Buisnessman', 'Politician', 'DefencePersonnels', 'Analyst',
#        'Clerks', 'ITProfessional', 'Farmer', 'Journalist', 'Lawyer',
#        'GovEmployee'], dtype=object)

# %% [markdown]
# ###### change the YES catergory to numeric

# %%
access_df.head()
# Out:
#    year                                     state     yes      no
# 0  2010  Nationwide (States, DC, and Territories)     85%     15%
# 1  2010                Nationwide (States and DC)     85%     15%
# 2  2010                                      Guam  77.80%  22.20%
# 3  2010                               Puerto Rico  92.10%   7.90%
# 4  2010                            Virgin Islands  69.40%  30.60%

# %%
access_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1640 entries, 0 to 1639
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    1640 non-null   int64
#  1   state   1640 non-null   object
#  2   yes     1640 non-null   object
#  3   no      1640 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 51.4+ KB

# %%
access_df['yes'] = access_df['yes'].map(lambda x: x.rstrip('%'))
access_df['yes'] = access_df['yes'].astype(float)

print(access_df.yes)
# Out:
# 0       85.0
# 1       85.0
# 2       77.8
# 3       92.1
# 4       69.4
#         ...
# 1635    79.9
# 1636    82.7
# 1637    85.4
# 1638    82.1
# 1639    86.1
# Name: yes, Length: 1640, dtype: float64

# %%
access_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1640 entries, 0 to 1639
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    1640 non-null   int64
#  1   state   1640 non-null   object
#  2   yes     1640 non-null   float64
#  3   no      1640 non-null   object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 51.4+ KB

# %%
access_df.describe()
# Out:
#               year          yes
# count  1640.000000  1640.000000
# mean   2002.665854    84.659634
# std       4.735653     4.908309
# min    1995.000000    65.900000
# 25%    1998.000000    81.600000
# 50%    2003.000000    85.400000
# 75%    2007.000000    88.300000
# max    2010.000000    95.700000

# %%
access_df
# Out:
#       year                                     state   yes      no
# 0     2010  Nationwide (States, DC, and Territories)  85.0     15%
# 1     2010                Nationwide (States and DC)  85.0     15%
# 2     2010                                      Guam  77.8  22.20%
# 3     2010                               Puerto Rico  92.1   7.90%
# 4     2010                            Virgin Islands  69.4  30.60%
# ...    ...                                       ...   ...     ...
# 1635  2010                                        AL  79.9  20.10%
# 1636  1996                                        MS  82.7  17.30%
# 1637  1996                                        VA  85.4  14.60%
# 1638  2006                                        WY  82.1  17.90%
# 1639  1996                                        TN  86.1  13.90%
#
# [1640 rows x 4 columns]

# %%
access_df['no'] = access_df['no'].map(lambda x: x.rstrip('%'))
access_df['no'] = access_df['no'].astype(float)

print(access_df.no)
# Out:
# 0       15.0
# 1       15.0
# 2       22.2
# 3        7.9
# 4       30.6
#         ...
# 1635    20.1
# 1636    17.3
# 1637    14.6
# 1638    17.9
# 1639    13.9
# Name: no, Length: 1640, dtype: float64

# %%
access_df
# Out:
#       year                                     state   yes    no
# 0     2010  Nationwide (States, DC, and Territories)  85.0  15.0
# 1     2010                Nationwide (States and DC)  85.0  15.0
# 2     2010                                      Guam  77.8  22.2
# 3     2010                               Puerto Rico  92.1   7.9
# 4     2010                            Virgin Islands  69.4  30.6
# ...    ...                                       ...   ...   ...
# 1635  2010                                        AL  79.9  20.1
# 1636  1996                                        MS  82.7  17.3
# 1637  1996                                        VA  85.4  14.6
# 1638  2006                                        WY  82.1  17.9
# 1639  1996                                        TN  86.1  13.9
#
# [1640 rows x 4 columns]

# %%
access_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1640 entries, 0 to 1639
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    1640 non-null   int64
#  1   state   1640 non-null   object
#  2   yes     1640 non-null   float64
#  3   no      1640 non-null   float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 51.4+ KB

# %%
plt.figure(figsize=(8,8));
sns.countplot(access_df['yes']);
plt.title("Yes for insurance Count");
plt.xticks(rotation = 45)
plt.show();
# Out:
# /Users/cuddoongaraado/opt/anaconda3/envs/data_capstone_venv/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(8,8));
sns.displot(access_df['no']);
plt.title("No for insurance Count");
plt.show();

# %%
plt.figure(figsize=(10,18));
sns.displot(insurance_df['city']);
plt.title("State Distribution");
plt.xticks(rotation = 45)
plt.show();

# %%
plt.figure(figsize=(10,18));
sns.displot(access_df['state']);
plt.title("State Distribution");
plt.xticks(rotation = 45)
plt.show();

# %%
access_df.head(10)
# Out:
#    year                                     state   yes    no
# 0  2010  Nationwide (States, DC, and Territories)  85.0  15.0
# 1  2010                Nationwide (States and DC)  85.0  15.0
# 2  2010                                      Guam  77.8  22.2
# 3  2010                               Puerto Rico  92.1   7.9
# 4  2010                            Virgin Islands  69.4  30.6
# 5  2009  Nationwide (States, DC, and Territories)  85.3  14.7
# 6  2009                Nationwide (States and DC)  85.6  14.4
# 7  2009                                      Guam  79.7  20.3
# 8  2009                               Puerto Rico  91.6   8.4
# 9  2009                            Virgin Islands  71.4  28.6

# %%
access_df= access_df[access_df['state']!= 'Guam'].copy()

# %%
access_df.state.unique()
# Out:
# array(['Nationwide (States, DC, and Territories)',
#        'Nationwide (States and DC)', 'Puerto Rico', 'Virgin Islands',
#        'NJ', 'TX', 'SC', 'VA', 'KY', 'CT', 'AZ', 'OR', 'ID', 'VT', 'MO',
#        'OK', 'MT', 'LA', 'IN', 'FL', 'NH', 'KS', 'District of Columbia',
#        'NM', 'AL', 'CA', 'WY', 'NY', 'SD', 'NV', 'MD', 'IA', 'MA', 'ME',
#        'NC', 'RI', 'NE', 'AR', 'MS', 'MN', 'HI', 'TN', 'ND', 'WV', 'CO',
#        'IL', 'UT', 'AK', 'DE', 'MI', 'WA', 'OH', 'WI', 'GA', 'PA'],
#       dtype=object)

# %%
access_df= access_df[access_df['state']!= 'Nationwide (States, DC, and Territories)'].copy()
access_df= access_df[access_df['state']!= 'Nationwide (States and DC)'].copy()
access_df= access_df[access_df['state']!= 'Puerto Rico'].copy()
access_df= access_df[access_df['state']!= 'Virgin Islands'].copy()
access_df.head()
# Out:
#      year state   yes    no
# 118  2009    NJ  84.8  15.2
# 119  2006    TX  71.0  29.0
# 120  2008    SC  79.1  20.9
# 121  2007    VA  88.2  11.8
# 122  1995    KY  83.1  16.9

# %%
access_df.state.nunique()
access_df.state.unique()
# Out:
# array(['NJ', 'TX', 'SC', 'VA', 'KY', 'CT', 'AZ', 'OR', 'ID', 'VT', 'MO',
#        'OK', 'MT', 'LA', 'IN', 'FL', 'NH', 'KS', 'DC', 'NM', 'AL', 'CA',
#        'WY', 'NY', 'SD', 'NV', 'MD', 'IA', 'MA', 'ME', 'NC', 'RI', 'NE',
#        'AR', 'MS', 'MN', 'HI', 'TN', 'ND', 'WV', 'CO', 'IL', 'UT', 'AK',
#        'DE', 'MI', 'WA', 'OH', 'WI', 'GA', 'PA'], dtype=object)

# %%
insurance_df.head()
# Out:
#     age  sex  weight   bmi  hereditary_diseases  no_of_dependents  smoker  \
# 0  60.0    0      64  24.3                    0                 1       0
# 1  49.0    1      75  22.6                    0                 1       0
# 2  32.0    1      64  17.8                    1                 2       1
# 3  61.0    1      53  36.4                    0                 1       1
# 4  19.0    1      50  20.6                    0                 0       0
#
#   city  diabetes  regular_ex    job_title    claim
# 0   NY         0           0        Actor  13112.6
# 1   MA         1           1     Engineer   9567.0
# 2   PA         1           1  Academician  32734.2
# 3   PA         1           0         Chef  48517.6
# 4   NY         1           0   HomeMakers   1731.7

# %%
insurance_df.rename(columns={'city': 'state'}, inplace=True)
insurance_df.rename(columns={'sex': 'gender'}, inplace=True)
insurance_df
# Out:
#         age  gender  weight   bmi  hereditary_diseases  no_of_dependents  \
# 0      60.0       0      64  24.3                    0                 1
# 1      49.0       1      75  22.6                    0                 1
# 2      32.0       1      64  17.8                    1                 2
# 3      61.0       1      53  36.4                    0                 1
# 4      19.0       1      50  20.6                    0                 0
# ...     ...     ...     ...   ...                  ...               ...
# 14995  39.0       0      49  28.3                    0                 1
# 14996  39.0       0      74  29.6                    0                 4
# 14997  20.0       0      62  33.3                    0                 0
# 14998  52.0       0      88  36.7                    0                 0
# 14999  52.0       0      57  26.4                    0                 3
#
#        smoker state  diabetes  regular_ex        job_title    claim
# 0           0    NY         0           0            Actor  13112.6
# 1           0    MA         1           1         Engineer   9567.0
# 2           1    PA         1           1      Academician  32734.2
# 3           1    PA         1           0             Chef  48517.6
# 4           0    NY         1           0       HomeMakers   1731.7
# ...       ...   ...       ...         ...              ...      ...
# 14995       1    SC         1           0        FilmMaker  21082.2
# 14996       0    FL         1           0          Student   7512.3
# 14997       0    FL         1           0  FashionDesigner   1391.5
# 14998       0    FL         1           0           Farmer   9144.6
# 14999       0    TN         1           0          Manager  25992.8
#
# [15000 rows x 12 columns]

# %%
insurance_df.state.nunique()
# Out:
# 36

# %%
insurance_df.replace({'Trenton': 'NJ', 'Warwick': 'CO' }, inplace=True)
insurance_df.city.unique()
# Out:
# array(['NY', 'MA', 'PA', 'NJ', 'OR', 'CT', 'IL', 'MD', 'York', 'CO', 'DC',
#        'RI', 'GA', 'AL', 'SC', 'NC', 'KY', 'TN', 'LA', 'TX', 'OK', 'FL',
#        'ND', 'IA', 'IN', 'OH', 'KS', 'MS', 'SD', 'NE', 'MN', 'MI', 'CA',
#        'AZ', 'NV', 'NM'], dtype=object)

# %%
access_df.replace({'District of Columbia': 'DC'}, inplace=True)
access_df.state.unique()
# Out:
# array(['NJ', 'TX', 'SC', 'VA', 'KY', 'CT', 'AZ', 'OR', 'ID', 'VT', 'MO',
#        'OK', 'MT', 'LA', 'IN', 'FL', 'NH', 'KS', 'DC', 'NM', 'AL', 'CA',
#        'WY', 'NY', 'SD', 'NV', 'MD', 'IA', 'MA', 'ME', 'NC', 'RI', 'NE',
#        'AR', 'MS', 'MN', 'HI', 'TN', 'ND', 'WV', 'CO', 'IL', 'UT', 'AK',
#        'DE', 'MI', 'WA', 'OH', 'WI', 'GA', 'PA'], dtype=object)

# %%
import seaborn as sns
from scipy.stats import zscore

# %%
# sns.boxplot(data=access_df['yes'])

# %%
access_df['yes'].describe()
# Out:
# count    1640.000000
# mean       84.659634
# std         4.908309
# min        65.900000
# 25%        81.600000
# 50%        85.400000
# 75%        88.300000
# max        95.700000
# Name: yes, dtype: float64

# %% [markdown]
# ## Summary statistics

# %% [markdown]
# ###### boxplot, histogram, then correlation,access to care.
